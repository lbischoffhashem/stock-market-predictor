# %%
import yfinance as yf
sp500 = yf.Ticker("^GSPC")
sp500 = sp500.history(period="max")
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-08-21 00:00:00-04:00  6380.830078  6393.649902  6352.709961  6370.169922
# 2025-08-22 00:00:00-04:00  6384.589844  6478.890137  6384.589844  6466.910156
# 2025-08-25 00:00:00-04:00  6457.669922  6466.890137  6438.060059  6439.319824
# 2025-08-26 00:00:00-04:00  6435.490234  6468.370117  6429.209961  6465.939941
# 2025-08-27 00:00:00-04:00  6462.259766  6487.060059  6457.839844  6481.399902
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2025-08-14 00:00:00-04:00', '2025-08-15 00:00:00-04:00',
#                '2025-08-18 00:00:00-04:00', '2025-08-19 00:00:00-04:00',
#                '2025-08-20 00:00:00-04:00', '2025-08-21 00:00:00-04:00',
#                '2025-08-22 00:00:00-04:00', '2025-08-25 00:00:00-04:00',
#                '2025-08-26 00:00:00-04:00', '2025-08-27 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24530, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-08-21 00:00:00-04:00  6380.830078  6393.649902  6352.709961  6370.169922
# 2025-08-22 00:00:00-04:00  6384.589844  6478.890137  6384.589844  6466.910156
# 2025-08-25 00:00:00-04:00  6457.669922  6466.890137  6438.060059  6439.319824
# 2025-08-26 00:00:00-04:00  6435.490234  6468.370117  6429.209961  6465.939941
# 2025-08-27 00:00:00-04:00  6462.259766  6487.060059  6457.839844  6481.399902
#
# ...

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-08-21 00:00:00-04:00  6380.830078  6393.649902  6352.709961  6370.169922
# 2025-08-22 00:00:00-04:00  6384.589844  6478.890137  6384.589844  6466.910156
# 2025-08-25 00:00:00-04:00  6457.669922  6466.890137  6438.060059  6439.319824
# 2025-08-26 00:00:00-04:00  6435.490234  6468.370117  6429.209961  6465.939941
# 2025-08-27 00:00:00-04:00  6462.259766  6487.060059  6457.839844  6481.399902
#
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy()
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2025-08-21 00:00:00-04:00  6380.830078  6393.649902  6352.709961  6370.169922
# 2025-08-22 00:00:00-04:00  6384.589844  6478.890137  6384.589844  6466.910156
# 2025-08-25 00:00:00-04:00  6457.669922  6466.890137  6438.060059  6439.319824
# 2025-08-26 00:00:00-04:00  6435.490234  6468.370117  6429.209961  6465.939941
# 2025-08-27 00:00:00-04:00  6462.259766  6487.060059  6457.839844  6481.399902
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=500, min_samples_split=100, random_state=1, n_jobs=-1)

# Percentage change from open to close (daily return)
sp500["OC_Pct_Change"] = (sp500["Close"] - sp500["Open"]) / sp500["Open"]

# Volatility (Range as a percentage of the open)
sp500["Daily_Volatility"] = (sp500["High"] - sp500["Low"]) / sp500["Open"]

# Where did the price close relative to its daily range?
sp500["Close_Relative_To_Range"] = (sp500["Close"] - sp500["Low"]) / (sp500["High"] - sp500["Low"])

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

#intial model ignoring volume for now.
predictors = ["OC_Pct_Change","Daily_Volatility","Close_Relative_To_Range"]

model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, n_estimators=500, n_jobs=-1,
#                        random_state=1)

# %%
from sklearn.metrics import precision_score
import pandas as pd


preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.6133333333333333

# %%
combined = pd.concat([test["Target"], preds],axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    probs = model.predict_proba(test[predictors])[:, 1]
    probs = pd.Series(probs, index=test.index, name="Predicted_Prob")
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds, probs],axis=1)
    return combined

# %%
def backtest(data, model, predictors, start = 2500, step = 250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1    4486
# 0    1994
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5425769059295587

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.536574
# 0    0.463426
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()
    '''exponential_moving_averages = sp500["Close"].ewm(span=horizon, adjust=False).mean()
    
    ema_column = f"Close_EMA_{horizon}"
    sp500[ema_column] = exponential_moving_averages

    EMA_ratio = f"Close_Ratio_EMA_{horizon}"
    sp500[EMA_ratio] = sp500["Close"] / sp500[ema_column]'''

    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors += [ratio_column, trend_column] #, ema_column, EMA_ratio

# %%
sp500 = sp500.dropna()
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2025-08-20 00:00:00-04:00  6406.620117  6408.399902  6343.859863  6395.779785
# 2025-08-21 00:00:00-04:00  6380.830078  6393.649902  6352.709961  6370.169922
# 2025-08-22 00:00:00-04:00  6384.589844  6478.890137  6384.589844  6466.910156
# 2025-08-25 00:00:00-04:00  6457.669922  6466.890137  6438.060059  6439.319824
# 2025-08-26 00:00:00-04:00  6435.490234  6468.370117  6429.209961  6465.939941
#
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1, n_jobs=-1)

# %%
'''
#making predictions probability threshold higher so we trade fewer days but when it estimates the stock/index will go up it is more confident in it
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= 0.6] = 1
    preds[preds < 0.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds],axis=1)
    return combined
    
predictors += new_predictors
predictions = predict(train, test, predictors, model)
predictions["Predictions"].value_counts()'''
# Out:
# '\n#making predictions probability threshold higher so we trade fewer days but when it estimates the stock/index will go up it is more confident in it\ndef predict(train, test, predictors, model):\n    model.fit(train[predictors], train["Target"])\n    preds = model.predict_proba(test[predictors])[:,1]\n    preds[preds >= 0.6] = 1\n    preds[preds < 0.6] = 0\n    preds = pd.Series(preds, index=test.index, name="Predictions")\n    combined = pd.concat([test["Target"], preds],axis=1)\n    return combined\n\npredictors += new_predictors\npredictions = predict(train, test, predictors, model)\npredictions["Predictions"].value_counts()'

# %%
# predictors.extend(new_predictors)
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1    3869
# 0    1610
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5549237529077281

# %%
from sklearn.metrics import f1_score
import numpy as np

def optimize_f1_score():
    best_f1 = 0
    best_thresh = 0
    
    for thresh in np.arange(0.25, 1.01, 0.01):
        preds = (predictions["Predicted_Prob"] >= thresh).astype(int)
        score = f1_score(predictions["Target"], preds, zero_division=0)
        if score > best_f1:
            best_f1 = score
            best_thresh = thresh
    return best_thresh, best_f1

# %%
import numpy as np
from sklearn.metrics import fbeta_score

def optimize_fbeta_score():
    best_fbeta = 0
    best_beta = 0.15
    best_thresh = 0

    for thresh in np.arange(0.51, 1.01, 0.01):
        y_pred = (predictions["Predicted_Prob"] >= thresh).astype(int)
        score = fbeta_score(predictions["Target"], y_pred, beta=best_beta, zero_division=0)
        
        if score > best_fbeta:
            best_fbeta = score
            best_thresh = thresh
    return best_thresh, best_fbeta

# %%
from sklearn.metrics import precision_recall_curve, fbeta_score

import numpy as np

precision_vals, recall_vals, thresholds = precision_recall_curve(predictions["Target"], predictions["Predicted_Prob"])

max_precision_idx = np.argmax(precision_vals[:-1])
max_precision_threshold = thresholds[max_precision_idx]
MP_trading_days = (predictions["Predicted_Prob"] >= max_precision_threshold).astype(int)
num_trading_days_MP = MP_trading_days.sum()

max_recall_idx = np.argmax(recall_vals[:-1])
max_recall_threshold = thresholds[max_recall_idx]
MR_trading_days = (predictions["Predicted_Prob"] >= max_recall_threshold).astype(int)
num_trading_days_MR = MR_trading_days.sum()

max_beta_threshold, max_fbeta = optimize_fbeta_score()
precision_at_max_beta = precision_score(predictions["Target"], (predictions["Predicted_Prob"] >= max_beta_threshold).astype(int), zero_division=0)
Mfb_trading_days = (predictions["Predicted_Prob"] >= max_beta_threshold).astype(int)
num_trading_days_Mfb = Mfb_trading_days.sum()

'''
max_f1_threshold, max_f1 = optimize_f1_score()
Mf1_trading_days = (predictions["Predicted_Prob"] >= max_f1_threshold).astype(int)
num_trading_days_Mf1 = Mf1_trading_days.sum()
'''

print(f"Max_precision: {precision_vals[max_precision_idx]} occurs at threshold: {max_precision_threshold} and has {num_trading_days_MP} trading days.")
print(f"Max_recall: {recall_vals[max_recall_idx]} occurs at threshold: {max_recall_threshold} and has {num_trading_days_MR} trading days.")
print(f"Max_recall: {max_fbeta} occurs at threshold: {max_beta_threshold} with {precision_at_max_beta} precision score and has {num_trading_days_Mfb} trading days.")
# print(f"Max_f1: {max_f1} occurs at threshold: {max_f1_threshold} and has {num_trading_days_Mf1} trading days.")
# Out:
# Max_precision: 1.0 occurs at threshold: 0.7304424755144316 and has 3 trading days.
# Max_recall: 1.0 occurs at threshold: 0.30304721701946913 and has 5479 trading days.
# Max_recall: 0.5689288254594681 occurs at threshold: 0.5700000000000001 with 0.5787589498806682 precision score and has 1676 trading days.
